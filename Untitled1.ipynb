# %%
a = read.csv('재택활동지수_2205.csv')

# %%
head(a)
# Out:
#   dt       age_cd sex_cd home_sido_nm h0d0h0_dur_r h0d0h1_dur_r h0d1h0_dur_r
# 1 20200831 0      \\N    \\N          0.06712914   0.9298201    0.1008356
# 2 20200831 10     \\N    \\N          0.07905599   0.9208362    0.1561438
# 3 20200831 20     \\N    \\N          0.17251841   0.8274004    0.3765829
# 4 20200831 30     \\N    \\N          0.16508122   0.8348874    0.4805249
# 5 20200831 40     \\N    \\N          0.15391753   0.8460634    0.4921565
# 6 20200831 50     \\N    \\N          0.15504685   0.8449338    0.4830282
#   h0d1h1_dur_r h1d0h0_dur_r h1d0h1_dur_r h1d1h0_dur_r h1d1h1_dur_r
# 1 0.8961136    0.11044102   0.8690769    0.1511613    0.8283539
# 2 0.8437484    0.09407905   0.9056237    0.1426144    0.8570873
# 3 0.6233359    0.20035382   0.7995792    0.2801702    0.7197628
# 4 0.5194437    0.18302351   0.8169353    0.3003714    0.6995874
# 5 0.5078244    0.15207456   0.8478991    0.2958528    0.7041209
# 6 0.5169525    0.15099449   0.8489658    0.3321713    0.6677890

# %%
table(is.na(a$home_sido_nm))
# Out:
# FALSE
#  2575

# %%
summary(a)
# Out:
#        dt              age_cd      sex_cd        home_sido_nm
#  Min.   :20200831   \\N    :1839   \\N:2391   \\N       :1011
#  1st Qu.:20210204   0      :  92   1  :  92   강원도    :  92
#  Median :20210712   10     :  92   2  :  92   경기도    :  92
#  Mean   :20211091   20     :  92              경상남도  :  92
#  3rd Qu.:20211220   30     :  92              경상북도  :  92
#  Max.   :20220530   40     :  92              광주광역시:  92
#                     (Other): 276              (Other)   :1104
#   h0d0h0_dur_r      h0d0h1_dur_r     h0d1h0_dur_r      h0d1h1_dur_r
#  Min.   :0.03497   Min.   :0.6770   Min.   :0.07916   Min.   :0.4412
#  1st Qu.:0.13545   1st Qu.:0.8398   1st Qu.:0.39859   1st Qu.:0.5536
#  Median :0.14781   Median :0.8516   Median :0.42359   Median :0.5759
#  Mean   :0.14278   Mean   :0.8565   Mean   :0.40644   Mean   :0.5929
#  3rd Qu.:0.15964   3rd Qu.:0.8643   3rd Qu.:0.44589   3rd Qu.:0.6011
#  Max.   :0.32292   Max.   :0.9642   Max.   :0.55851   Max.   :0.9200
#
# ...
